# %%
# !pip install pywget
# !pip install opencv-python
# !pip install wget
# Out:
# Requirement already satisfied: pywget in c:\users\sophi\anaconda3\lib\site-packages (0.31)
# Requirement already satisfied: opencv-python in c:\users\sophi\anaconda3\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\sophi\anaconda3\lib\site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: wget in c:\users\sophi\anaconda3\lib\site-packages (3.2)

# %%
import wget
import cv2
import glob

img=[]
for file in glob.glob('imagenperros.jpg'):
    img.append(cv2.imread(file))

idx=0
print('Shape:{}'.format(img[idx].shape))
# Los dos primeros indices representan el pixel i,j 
# el último indice representa el canal (BGR)
print(img[idx])

cv2.imshow('imagenperros', img[idx])
cv2.waitKey(0) # Espera hasta que se presione alguna tecla para continuar
cv2.destroyAllWindows() # Cierra todas las ventanas abiertas por OpenCV

def view(img):
    cv2.imshow("imagenperros", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

view(img)
# Out:
# Shape:(576, 1024, 3)
# [[[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  ...
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]
#
#  [[254 254 254]
#   [254 254 254]
#   [254 254 254]
#   ...
#   [254 254 254]
#   [254 254 254]
#   [254 254 254]]]
